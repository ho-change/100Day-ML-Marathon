# %% [markdown]
# ## 作業1：Microsoft Malware Prediction
# #### 1.你選的這組資料為何重要
#     這個競賽尋找哪些電腦容易受到惡意程式的入侵，提供電腦等相關數據，分析哪些電腦較容易成為受害者
#
# #### 2.資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#     提供者微軟，透過收集各種主機的資料，例如系統版本、防毒程式運作情形，註冊表的相關訊息等等，作為數據資料的來源。
#
# #### 3.蒐集而來的資料型態為何
#     結構化：數值、表格，每個欄位都是代號或是版本號等訊息
#
# #### 4.這組資料想解決的問題如何評估
#     預測哪些模式組合容易受到攻擊，可以使用ROC曲線，得出較容易受到攻擊的電腦有哪些特徵。

# %% [markdown]
# ## 作業2：想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
# #### 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#     提升業績，來自於客人喜歡搭乘計程車，而採用自家計程車車隊。節省成本支出，或是提高收入的方式
#     我的假設，在客人需要搭計程車的地房駐點或徘徊，減少呼叫時間，以及汽油消耗提升每次利率
#
# #### 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#     對於客人上/下車站點做收集紀錄，路線的循環紀錄，尋找下個客人最近的相似點，減少不必要的空趟來回。
#
# #### 3. 蒐集而來的資料型態為何
#     地圖路徑、上車時間、地點等等...
#
# #### 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
#     透過將數據收集，找出集中度最高的地方，來確認最容易叫計程車上車的地點，再根據下車地點來決定下次上車的路徑。

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
def mean_squared_error1(x1,x2):
    sub_arr = x2 - x1
    print (sub_arr)
    x3 = sub_arr**2
    print (x3)
    x3_length = len(x3)
    
    x3_sum = x3.sum()
    print ("x3_sum %d" %(x3_sum))
    print ("x3_length = %d" %(x3_length))
    return x3_sum / x3_length
    """
    請完成這個 Function 後往下執行
    """

# %%
def mean_squared_error(x1,x2):
    arr = (x1 - x2)**2
    return arr.sum() / len(x1)

# %%
def mean_absolute_error(x1,x2):
    arr = abs(x1 - x2)
    return arr.sum() / len(x1)

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 216.653
# The Mean absolute error is 11.863
